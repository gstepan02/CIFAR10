# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os
import torchvision
import torchvision.transforms as transforms

# %%
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride = 1):
        super(BasicBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size = 3, stride = stride, padding = 1, bias = False)
        self.bn1 = nn.BatchNorm2d(planes)

        self.conv2 = nn.Conv2d(planes,planes,kernel_size = 3, stride = 1, padding = 1, bias = False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Identity()
        if stride != 1:
            self.shortcut = nn.Sequential(
                            nn.Conv2d(in_planes, planes, kernel_size = 1, stride = stride, bias = False),
                            nn.BatchNorm2d(planes)
                            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)

        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes = 10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3,64,kernel_size = 3, stride = 1, padding = 1, bias = False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride = 1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride = 2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride = 2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride = 2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []

        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes

        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1) # out.size(0) = out.reshape(0)
        out = self.linear(out)

        return out

# %%
train = transforms.Compose([
    transforms.RandomCrop(32, padding = 4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root= './data', train = True, download = True, transform = train)
test_dataset = torchvision.datasets.CIFAR10(root= './data', train = False, download = True, transform = test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = 128, shuffle = True, num_workers = 4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 100, shuffle = False, num_workers = 4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
def ResNet18():
    return ResNet(BasicBlock, [2,2,2,2])

# %%
device = 'cuda'
cudnn.benchmark = True

net = ResNet18()
net = net.to(device)
net = torch.nn.DataParallel(net)

learning_rate = 0.1
file_name = 'resnet18_cifar10.pth'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = learning_rate, momentum = 0.9, weight_decay = 0.0002)

# %%
def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in  enumerate(train_loader):
        inputs= inputs.to(device)
        targets = targets.to(device)

        outputs = net(inputs)

        optimizer.zero_grad()
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)

# %%
def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

# %%
def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 100:
        lr /= 10
    if epoch >= 150:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
for epoch in range(0, 20):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current benign train accuracy: 0.078125
# Current benign train loss: 2.4161665439605713
#
# Current batch: 100
# Current benign train accuracy: 0.2578125
# Current benign train loss: 2.0340278148651123
#
# Current batch: 200
# Current benign train accuracy: 0.296875
# Current benign train loss: 1.8409966230392456
#
# Current batch: 300
# Current benign train accuracy: 0.34375
# Current benign train loss: 1.7640700340270996
#
# Total benign train accuarcy: 28.848
# Total benign train loss: 790.1268329620361
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 38.67
# Test average loss: 0.017548961484432222
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.4609375
# Current benign train loss: 1.4852935075759888
#
# Current batch: 100
# Current benign train accuracy: 0.5
# Current benign train loss: 1.4296295642852783
#
# Current batch: 200
# Current benign train accuracy: 0.4453125
# Current benign train loss: 1.4241976737976074
#
# Current batch: 300
# Current benign train accuracy: 0.5
# Current benign train loss: 1.4308282136917114
#
# Total benign train accuarcy: 45.584
# Total benign train loss: 578.5272495746613
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 50.64
# Test average loss: 0.013403666651248931
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5390625
# Current benign train loss: 1.1776936054229736
#
# Current batch: 100
# Current benign train accuracy: 0.515625
# Current benign train loss: 1.283424973487854
#
# Current batch: 200
# Current benign train accuracy: 0.515625
# Current benign train loss: 1.3411551713943481
#
# Current batch: 300
# Current benign train accuracy: 0.609375
# Current benign train loss: 1.1945905685424805
#
# Total benign train accuarcy: 55.348
# Total benign train loss: 485.00874215364456
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 55.91
# Test average loss: 0.0126853373169899
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5234375
# Current benign train loss: 1.3490324020385742
#
# Current batch: 100
# Current benign train accuracy: 0.6171875
# Current benign train loss: 0.9896416664123535
#
# Current batch: 200
# Current benign train accuracy: 0.65625
# Current benign train loss: 1.0637246370315552
#
# Current batch: 300
# Current benign train accuracy: 0.625
# Current benign train loss: 1.1303431987762451
#
# Total benign train accuarcy: 63.5
# Total benign train loss: 402.7446832060814
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 49.12
# Test average loss: 0.014184522724151612
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.0414137840270996
#
# Current batch: 100
# Current benign train accuracy: 0.6171875
# Current benign train loss: 0.9517923593521118
#
# Current batch: 200
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.7726293206214905
#
# Current batch: 300
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.8462729454040527
#
# Total benign train accuarcy: 68.49
# Total benign train loss: 348.587971329689
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 64.41
# Test average loss: 0.010101207888126374
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.8299735188484192
#
# Current batch: 100
# Current benign train accuracy: 0.671875
# Current benign train loss: 0.8214394450187683
#
# Current batch: 200
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.7295781970024109
#
# Current batch: 300
# Current benign train accuracy: 0.65625
# Current benign train loss: 0.8390317559242249
#
# Total benign train accuarcy: 73.022
# Total benign train loss: 299.4558882713318
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 73.85
# Test average loss: 0.007425785893201828
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6538844108581543
#
# Current batch: 100
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.650529682636261
#
# Current batch: 200
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6631922125816345
#
# Current batch: 300
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.46979719400405884
#
# Total benign train accuarcy: 77.01
# Total benign train loss: 257.70417031645775
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 73.96
# Test average loss: 0.007432034111022949
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.6408601403236389
#
# Current batch: 100
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.7675060629844666
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.48999226093292236
#
# Current batch: 300
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6103171706199646
#
# Total benign train accuarcy: 79.56
# Total benign train loss: 229.30814635753632
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 77.03
# Test average loss: 0.00664035165309906
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.48851802945137024
#
# Current batch: 100
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5729619264602661
#
# Current batch: 200
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5399771928787231
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5680356025695801
#
# Total benign train accuarcy: 81.906
# Total benign train loss: 204.43982297182083
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 77.71
# Test average loss: 0.006526682442426682
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5025578737258911
#
# Current batch: 100
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.3654932975769043
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5519003868103027
#
# Current batch: 300
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.592422366142273
#
# Total benign train accuarcy: 83.248
# Total benign train loss: 186.08199056982994
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 80.7
# Test average loss: 0.005701816670596599
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5796314477920532
#
# Current batch: 100
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.43663060665130615
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4631894826889038
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5068852305412292
#
# Total benign train accuarcy: 84.776
# Total benign train loss: 170.25200901925564
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 82.44
# Test average loss: 0.0052765056848526
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.38049623370170593
#
# Current batch: 100
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3019861578941345
#
# Current batch: 200
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.3967040777206421
#
# Current batch: 300
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.3099786639213562
#
# Total benign train accuarcy: 85.662
# Total benign train loss: 161.7069485038519
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 82.83
# Test average loss: 0.005101148867607117
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2779412865638733
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.41547247767448425
#
# Current batch: 200
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.359947144985199
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.45178675651550293
#
# Total benign train accuarcy: 86.514
# Total benign train loss: 151.14924056828022
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 83.44
# Test average loss: 0.005004959163069725
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5018453598022461
#
# Current batch: 100
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4503873288631439
#
# Current batch: 200
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.3644731342792511
#
# Current batch: 300
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.24315732717514038
#
# Total benign train accuarcy: 87.468
# Total benign train loss: 142.2157876342535
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 79.48
# Test average loss: 0.00644746113717556
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.4142252206802368
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4072858691215515
#
# Current batch: 200
# Current benign train accuracy: 0.875
# Current benign train loss: 0.337582528591156
#
# Current batch: 300
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3314664959907532
#
# Total benign train accuarcy: 87.906
# Total benign train loss: 136.05463761091232
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 84.79
# Test average loss: 0.004545100612938404
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.875
# Current benign train loss: 0.4226185381412506
#
# Current batch: 100
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3299214541912079
#
# Current batch: 200
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.318938285112381
#
# Current batch: 300
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.27762100100517273
#
# Total benign train accuarcy: 88.39
# Total benign train loss: 129.87384817004204
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 82.48
# Test average loss: 0.00555184853374958
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5524894595146179
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.31404855847358704
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.38494202494621277
#
# Current batch: 300
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.3902370035648346
#
# Total benign train accuarcy: 88.798
# Total benign train loss: 126.07847663760185
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 83.94
# Test average loss: 0.005049480494856835
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.27409806847572327
#
# Current batch: 100
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.34949636459350586
#
# Current batch: 200
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3057290315628052
#
# Current batch: 300
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.3326595723628998
#
# Total benign train accuarcy: 89.532
# Total benign train loss: 119.49821038544178
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 85.77
# Test average loss: 0.004204181465506554
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.23483701050281525
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.1940385401248932
#
# Current batch: 200
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.23528273403644562
#
# Current batch: 300
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.22861240804195404
#
# Total benign train accuarcy: 89.644
# Total benign train loss: 116.27699079364538
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 84.75
# Test average loss: 0.004356096994876862
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.22542455792427063
#
# Current batch: 100
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3500388562679291
#
# Current batch: 200
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.1808854639530182
#
# Current batch: 300
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5538946390151978
#
# Total benign train accuarcy: 90.03
# Total benign train loss: 112.42608098685741
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 85.04
# Test average loss: 0.004640522158145905
# Model Saved!

# %%
def test_model_on_test_set(model, test_loader):
    model.eval()

    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f'Accuracy on test set: {accuracy:.2f}%')

def load_model_with_prefix(model, checkpoint_path):
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict({k.replace('module.', ''): v for k, v in checkpoint['net'].items()})

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = ResNet18()
model = model.to(device)

checkpoint_path = './checkpoint/' + file_name
if os.path.exists(checkpoint_path):
    load_model_with_prefix(model, checkpoint_path)
    print('Model weights loaded successfully!')
else:
    print('Model weights not found.')

test_model_on_test_set(model, test_loader)
# Out:
# Model weights loaded successfully!
# Accuracy on test set: 85.04%
